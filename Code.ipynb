# %% [markdown]
# <a href="https://colab.research.google.com/github/SameenRafi/Data-Science-Project---Factors-affecting-US-House-Prices-over-the-last-20-years./blob/main/Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Sameen Rafi Mir
# sameenrafi5@gmail.com
# Assignment for Home.LLC
# Used 7 Factors***
#
# All of the data is downloaded from S&P/Case-Shiller.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# House Price Index

# %%
y_hpi = pd.read_csv("/content/HPI.csv").rename(columns = {"DATE" : "Period", "CSUSHPISA" : "PI"})

# %%
y_hpi.head(10)
# Out:
#        Period       PI
# 0  2002-01-01  117.144
# 1  2002-02-01  117.845
# 2  2002-03-01  118.687
# 3  2002-04-01  119.611
# 4  2002-05-01  120.724
# 5  2002-06-01  121.813
# 6  2002-07-01  122.888
# 7  2002-08-01  123.830
# 8  2002-09-01  124.780
# 9  2002-10-01  125.735

# %%
y_hpi['PI'] = y_hpi['PI'].round(2)

# %%
y_hpi['Period'] = pd.to_datetime(y_hpi['Period'])

# %%
y_hpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Period  253 non-null    datetime64[ns]
#  1   PI      253 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.1 KB

# %% [markdown]
# 1. Mortgage

# %%
mortgage = pd.read_csv("/content/MORTGAGE30US (1).csv").rename(columns={'DATE': 'Period', 'MORTGAGE30US' : 'Mortgage'})
mortgage.head(10)
# Out:
#        Period  Mortgage
# 0  2002-01-01    6.9975
# 1  2002-02-01    6.8925
# 2  2002-03-01    7.0140
# 3  2002-04-01    6.9850
# 4  2002-05-01    6.8060
# 5  2002-06-01    6.6500
# 6  2002-07-01    6.4850
# 7  2002-08-01    6.2900
# 8  2002-09-01    6.0925
# 9  2002-10-01    6.1125

# %%
mortgage['Mortgage'] = mortgage['Mortgage'].round(2)
mortgage.head(10)
# Out:
#        Period  Mortgage
# 0  2002-01-01      7.00
# 1  2002-02-01      6.89
# 2  2002-03-01      7.01
# 3  2002-04-01      6.98
# 4  2002-05-01      6.81
# 5  2002-06-01      6.65
# 6  2002-07-01      6.48
# 7  2002-08-01      6.29
# 8  2002-09-01      6.09
# 9  2002-10-01      6.11

# %%
mortgage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Period    253 non-null    object
#  1   Mortgage  253 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.1+ KB

# %%
mortgage['Period'] = pd.to_datetime(mortgage['Period'])

# %%
mortgage.head()
# Out:
#       Period  Mortgage
# 0 2002-01-01      7.00
# 1 2002-02-01      6.89
# 2 2002-03-01      7.01
# 3 2002-04-01      6.98
# 4 2002-05-01      6.81

# %%
mortgage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Period    253 non-null    datetime64[ns]
#  1   Mortgage  253 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.1 KB

# %% [markdown]
# 2. Homes Sold

# %%
homes_sold = pd.read_csv("/content/Homesold.csv").rename(columns={'DATE': 'Period', 'HSN1F' : 'homesold'})
homes_sold.head()
# Out:
#        Period  homesold
# 0  2002-01-01     880.0
# 1  2002-02-01     948.0
# 2  2002-03-01     923.0
# 3  2002-04-01     936.0
# 4  2002-05-01     978.0

# %%
homes_sold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Period    253 non-null    object
#  1   homesold  253 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.1+ KB

# %%
homes_sold['Period'] = pd.to_datetime(homes_sold['Period'])

# %%
homes_sold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Period    253 non-null    datetime64[ns]
#  1   homesold  253 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.1 KB

# %% [markdown]
# 3. Homes for Sale

# %%
hfor_sale = pd.read_csv("/content/Homesforsale.csv").rename(columns={'DATE': 'Period', 'HNFSEPUSSA' : 'homesforsale'})
hfor_sale.head(10)
# Out:
#        Period  homesforsale
# 0  2002-01-01         310.0
# 1  2002-02-01         313.0
# 2  2002-03-01         316.0
# 3  2002-04-01         324.0
# 4  2002-05-01         327.0
# 5  2002-06-01         328.0
# 6  2002-07-01         333.0
# 7  2002-08-01         334.0
# 8  2002-09-01         333.0
# 9  2002-10-01         335.0

# %%
hfor_sale['Period'] = pd.to_datetime(hfor_sale['Period'])

# %%
hfor_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Period    253 non-null    datetime64[ns]
#  1   homesold  253 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.1 KB

# %% [markdown]
# 4. Construction Spending in USA

# %%
Cons_spend = pd.read_csv("/content/ConsSpens.csv").rename(columns={'DATE': 'Period', 'TTLCONS' : 'Cost'})

# %%
Cons_spend.head(10)
# Out:
#        Period      Cost
# 0  2002-01-01  858654.0
# 1  2002-02-01  862338.0
# 2  2002-03-01  844551.0
# 3  2002-04-01  858240.0
# 4  2002-05-01  850935.0
# 5  2002-06-01  846777.0
# 6  2002-07-01  847129.0
# 7  2002-08-01  839008.0
# 8  2002-09-01  832134.0
# 9  2002-10-01  839690.0

# %%
Cons_spend['Period'] = pd.to_datetime(Cons_spend['Period'])

# %%
Cons_spend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Period  253 non-null    datetime64[ns]
#  1   Cost    253 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.1 KB

# %% [markdown]
# 5. Unemployment in US

# %%
un_rate = pd.read_csv('/content/UNRATE.csv').rename(columns = {'DATE': 'Period', 'UNRATE': 'unemployment'})

# %%
un_rate.head()
# Out:
#        Period  unemployment
# 0  2002-01-01           5.7
# 1  2002-02-01           5.7
# 2  2002-03-01           5.7
# 3  2002-04-01           5.9
# 4  2002-05-01           5.8

# %%
un_rate['Period'] = pd.to_datetime(un_rate['Period'])

# %%
un_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Period        253 non-null    datetime64[ns]
#  1   unemployment  253 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.1 KB

# %% [markdown]
# 6. Personal Savings in US

# %%
pers_sav = pd.read_csv("/content/Personalsavings.csv").rename(columns = {'DATE' : 'Period', 'PMSAVE' : 'savings'})
pers_sav.head(10)
# Out:
#        Period  savings
# 0  2002-01-01    441.6
# 1  2002-02-01    429.0
# 2  2002-03-01    440.3
# 3  2002-04-01    431.9
# 4  2002-05-01    495.0
# 5  2002-06-01    497.4
# 6  2002-07-01    431.2
# 7  2002-08-01    424.4
# 8  2002-09-01    469.0
# 9  2002-10-01    459.5

# %%
pers_sav['Period'] = pd.to_datetime(pers_sav['Period'])

# %%
pers_sav.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Period   253 non-null    datetime64[ns]
#  1   savings  253 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.1 KB

# %% [markdown]
# 7. Disposable Income in USA

# %%
disp_inc = pd.read_csv('/content/Disposableincome.csv').rename(columns={'DATE' : 'Period', 'DSPIC96' : 'Dispinc'})
disp_inc.head()
# Out:
#        Period  Dispinc
# 0  2002-01-01  10514.7
# 1  2002-02-01  10531.6
# 2  2002-03-01  10539.0
# 3  2002-04-01  10574.2
# 4  2002-05-01  10616.5

# %%
disp_inc['Period'] = pd.to_datetime(disp_inc['Period'])

# %%
disp_inc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Period   253 non-null    datetime64[ns]
#  1   Dispinc  253 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.1 KB

# %% [markdown]
# 8. Houses starting construction in US monthly

# %%
house_start = pd.read_csv('/content/HOUST.csv').rename(columns = {'DATE' : 'Period', 'HOUST' : 'housesstarted'})
house_start.head()
# Out:
#        Period  housesstarted
# 0  2002-01-01         1698.0
# 1  2002-02-01         1829.0
# 2  2002-03-01         1642.0
# 3  2002-04-01         1592.0
# 4  2002-05-01         1764.0

# %%
house_start['Period'] = pd.to_datetime(house_start['Period'])

# %%
house_start.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Period         253 non-null    datetime64[ns]
#  1   housesstarted  253 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.1 KB

# %% [markdown]
# Combining the Data.

# %%
dfs = [mortgage, homes_sold, hfor_sale, Cons_spend, un_rate, pers_sav, disp_inc, house_start]

# %%
X_monthly = pd.merge(dfs[0], dfs[1], how = 'outer', on = 'Period')

# %%
X_monthly.head()
# Out:
#       Period  Mortgage  homesold
# 0 2002-01-01      7.00     880.0
# 1 2002-02-01      6.89     948.0
# 2 2002-03-01      7.01     923.0
# 3 2002-04-01      6.98     936.0
# 4 2002-05-01      6.81     978.0

# %%
for df in dfs[2:]:
  X_monthly = pd.merge(X_monthly, df, how = 'outer', on = 'Period')

# %%
X_monthly.set_index('Period', inplace = True)

# %%
X_monthly.head(10)
# Out:
#             Mortgage  homesold  homesforsale      Cost  unemployment  savings  \
# Period
# 2002-01-01      7.00     880.0         310.0  858654.0           5.7    441.6
# 2002-02-01      6.89     948.0         313.0  862338.0           5.7    429.0
# 2002-03-01      7.01     923.0         316.0  844551.0           5.7    440.3
# 2002-04-01      6.98     936.0         324.0  858240.0           5.9    431.9
# 2002-05-01      6.81     978.0         327.0  850935.0           5.8    495.0
# 2002-06-01      6.65     957.0         328.0  846777.0           5.8    497.4
# 2002-07-01      6.48     956.0         333.0  847129.0           5.8    431.2
# 2002-08-01      6.29    1014.0         334.0  839008.0           5.7    424.4
# 2002-09-01      6.09    1044.0         333.0  832134.0           5.7    469.0
# 2002-10-01      6.11    1006.0         335.0  839690.0           5.7    459.5
#
#             Dispinc  housesstarted
# Period
# 2002-01-01  10514.7         1698.0
# ...

# %%
X_monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 253 entries, 2002-01-01 to 2023-01-01
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Mortgage       253 non-null    float64
#  1   homesold       253 non-null    float64
#  2   homesforsale   253 non-null    float64
#  3   Cost           253 non-null    float64
#  4   unemployment   253 non-null    float64
#  5   savings        253 non-null    float64
#  6   Dispinc        253 non-null    float64
#  7   housesstarted  253 non-null    float64
# dtypes: float64(8)
# memory usage: 17.8 KB

# %%
y_hpi.head()
# Out:
#        Period      PI
# 0  2002-01-01  117.14
# 1  2002-02-01  117.84
# 2  2002-03-01  118.69
# 3  2002-04-01  119.61
# 4  2002-05-01  120.72

# %%
X = X_monthly[['Mortgage', 'homesold', 'homesforsale', 'Cost', 'unemployment', 'savings', 'Dispinc', 'housesstarted']]

# %%
X.head(10)
# Out:
#             Mortgage  homesold  homesforsale      Cost  unemployment  savings  \
# Period
# 2002-01-01      7.00     880.0         310.0  858654.0           5.7    441.6
# 2002-02-01      6.89     948.0         313.0  862338.0           5.7    429.0
# 2002-03-01      7.01     923.0         316.0  844551.0           5.7    440.3
# 2002-04-01      6.98     936.0         324.0  858240.0           5.9    431.9
# 2002-05-01      6.81     978.0         327.0  850935.0           5.8    495.0
# 2002-06-01      6.65     957.0         328.0  846777.0           5.8    497.4
# 2002-07-01      6.48     956.0         333.0  847129.0           5.8    431.2
# 2002-08-01      6.29    1014.0         334.0  839008.0           5.7    424.4
# 2002-09-01      6.09    1044.0         333.0  832134.0           5.7    469.0
# 2002-10-01      6.11    1006.0         335.0  839690.0           5.7    459.5
#
#             Dispinc  housesstarted
# Period
# 2002-01-01  10514.7         1698.0
# ...

# %%
y = y_hpi[['PI']]

# %%
y.head(10)
# Out:
#        PI
# 0  117.14
# 1  117.84
# 2  118.69
# 3  119.61
# 4  120.72
# 5  121.81
# 6  122.89
# 7  123.83
# 8  124.78
# 9  125.74

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 253 entries, 2002-01-01 to 2023-01-01
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Mortgage       253 non-null    float64
#  1   homesold       253 non-null    float64
#  2   homesforsale   253 non-null    float64
#  3   Cost           253 non-null    float64
#  4   unemployment   253 non-null    float64
#  5   savings        253 non-null    float64
#  6   Dispinc        253 non-null    float64
#  7   housesstarted  253 non-null    float64
# dtypes: float64(8)
# memory usage: 17.8 KB

# %% [markdown]
# Splitting the Data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# Combing Price Index and features

# %%
tdata = [mortgage, homes_sold, hfor_sale, Cons_spend, un_rate, pers_sav, disp_inc, house_start, y_hpi]

# %%
X_period = pd.merge(tdata[0], tdata[1], how = 'outer', on = 'Period')

# %%
for dft in tdata[2:]:
  X_period = pd.merge(X_period, dft, how = 'outer', on = 'Period')

# %%
X_period.head()
# Out:
#       Period  Mortgage  homesold  homesforsale      Cost  unemployment  \
# 0 2002-01-01      7.00     880.0         310.0  858654.0           5.7
# 1 2002-02-01      6.89     948.0         313.0  862338.0           5.7
# 2 2002-03-01      7.01     923.0         316.0  844551.0           5.7
# 3 2002-04-01      6.98     936.0         324.0  858240.0           5.9
# 4 2002-05-01      6.81     978.0         327.0  850935.0           5.8
#
#    savings  Dispinc  housesstarted      PI
# 0    441.6  10514.7         1698.0  117.14
# 1    429.0  10531.6         1829.0  117.84
# 2    440.3  10539.0         1642.0  118.69
# 3    431.9  10574.2         1592.0  119.61
# 4    495.0  10616.5         1764.0  120.72
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Mortgage'].plot(kind='hist', bins=20, title='Mortgage')
# ...

# %% [markdown]
# Can plot the Home price index with respect to two different Factors eg Mortgage and Savings.

# %%
plt.figure(figsize=(15, 8))
sns.scatterplot(x = 'Mortgage', y = 'savings', data = X_period, hue = 'PI', palette = 'coolwarm')
# Out:
# <Axes: xlabel='Mortgage', ylabel='savings'>

# %% [markdown]
# Relationship between feature and target variable

# %%
plt.figure(figsize = (15,8))
sns.heatmap(X_period.corr(), annot=True, cmap='YlGnBu')
# Out:
# <ipython-input-133-a48626240d06>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(X_period.corr(), annot=True, cmap='YlGnBu')
# <Axes: >

# %% [markdown]
# US House Price Predictions Using Linear Regression and Random forest.

# %% [markdown]
# 1. Simple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred[0:10]
# Out:
# array([[138.3509135 ],
#        [138.92026611],
#        [139.45057631],
#        [150.81018041],
#        [180.08527784],
#        [208.52323088],
#        [143.1547839 ],
#        [146.41012951],
#        [147.62111634],
#        [206.21325458]])

# %%
print(model.score(X_train,y_train))
# Out:
# 0.9866335899236995

# %%
print(model.score(X_test,y_test))
# Out:
# 0.9690251557606417

# %%
print(y_test.describe())
# Out:
#                PI
# count   51.000000
# mean   172.725098
# std     29.429267
# min    117.140000
# 25%    148.375000
# 50%    170.880000
# 75%    190.980000
# max    258.360000

# %% [markdown]
# Calculating feature importance of each factors after the Linear Regression model is trained.

# %%
coefficients = model.coef_

# %%
for i, coefficient in enumerate(coefficients):
    print(f"Feature '{factors[0:]}' has coefficient: {coefficient}")
# Out:
# Feature '['Period', 'Mortgage', 'homesold', 'homesforsale', 'Cost', 'unemployment', 'savings', 'Dispinc', 'housesstarted']' has coefficient: [ 2.37585975e+00 -2.80425914e-02  6.93659808e-02  8.92334553e-05
#   5.97692186e+00 -2.19395538e-02  1.57727264e-02  2.66590965e-02]

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(X_train,y_train)
# Out:
# <ipython-input-162-c5573e33875d>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(X_train,y_train)
# RandomForestRegressor()

# %%
forest.score(X_test,y_test)
# Out:
# 0.9916538672171162

# %% [markdown]
# Calculating the feature importance of each factor after Random forest is trained.

# %%
factors = ['Period', 'Mortgage', 'homesold', 'homesforsale', 'Cost', 'unemployment', 'savings', 'Dispinc', 'housesstarted']

# %%
feature_importances = forest.feature_importances_

# %%
for i, feature_importance in enumerate(feature_importances):
    print(f"Feature '{factors[i]}' has importance: {feature_importance}")
# Out:
# Feature 'Period' has importance: 0.0033909366399048234
# Feature 'Mortgage' has importance: 0.0018149921489338458
# Feature 'homesold' has importance: 0.02532573393099138
# Feature 'homesforsale' has importance: 0.5353300633811172
# Feature 'Cost' has importance: 0.014084749628217234
# Feature 'unemployment' has importance: 0.010967301016999623
# Feature 'savings' has importance: 0.4085337361444785
# Feature 'Dispinc' has importance: 0.000552487109357429

# %% [markdown]
# Actual Values vs Predicted vaues.

# %%
forestres = pd.DataFrame({'Actual' : y_test.squeeze(), 'PredictedviaRF' : y_rpred.squeeze()})

# %%
forestres.head(15)
# Out:
#      Actual  PredictedviaRF
# 108  141.52        139.9193
# 130  144.58        145.0627
# 107  142.06        142.6950
# 32   154.18        155.8399
# 62   184.15        182.6576
# 201  205.11        204.5702
# 101  145.72        145.0593
# 96   147.40        146.4952
# 98   145.86        146.5218
# 202  205.67        204.3947
# 206  207.07        207.3210
# 42   172.86        174.2481
# 233  258.36        256.0341
# 23   140.18        143.0092
# 160  170.88        172.3594
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['Actual'].plot(kind='hist', bins=20, title='Actual')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['PredictedviaRF'].plot(kind='hist', bins=20, title='PredictedviaRF')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
from matplotlib import pyplot as plt
_df_18.plot(kind='scatter', x='Actual', y='PredictedviaRF', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# **Thank you for your attention.**
